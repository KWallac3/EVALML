# %% [markdown]
# <a href="https://colab.research.google.com/github/KWallac3/EVALML/blob/main/TRACE_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tabula

# Read PDF into list of DataFrame
df = tabula.read_pdf("2022 Country Risk Scores.pdf", pages='all', multiple_tables=True)

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
py_url = "https://www.traceinternational.org/trace-matrix#matrix-results"
ppy_page = requests.get(py_url)
py_soup = BeautifulSoup (ppy_page.text, 'html.parser')
df = py_soup.prettify()

# %%
df
# Out:
# '<!DOCTYPE doctype html>\n<html data-n-head-ssr="" lang="en">\n <head>\n  <title>\n   TRACE Bribery Risk Matrix | View Country Risk Scores\n  </title>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="Measures business bribery risk in over 194 jurisdictions. The first risk index created specifically for compliance professionals" name="description"/>\n  <meta charset="utf-8" data-n-head="ssr"/>\n  <meta content="width=device-width,initial-scale=1" data-n-head="ssr" name="viewport"/>\n  <link href="/favicon.ico" rel="shortcut icon"/>\n  <link data-n-head="ssr" href="https://use.typekit.net/uwc4aaa.css" rel="stylesheet"/>\n  <link data-n-head="ssr" href="https://fonts.googleapis.com/css?family=Lora&amp;amp;display=swap" rel="stylesheet"/>\n  <script crossorigin="anonymous" src="https://kit.fontawesome.com/6e3d3f661f.js">\n  </script>\n  <link href="/bundles/main-css?v=Mk9CzhqpOLDJwfvR4WeYjwPK_N_M5fWzAcfL8Jnil0k1" rel="stylesheet">\n   <link href="
# ...

# %%
trace_matrix = pd.read_html(df)

# %%
from IPython.core.display import display_pretty
display(trace_matrix)
# Out:
# [     Rank            Country  Risk Score  \
#  0       1             Norway           4
#  1       2        New Zealand           8
#  2       3             Sweden           9
#  3       4        Switzerland          10
#  4       5            Denmark          11
#  ..    ...                ...         ...
#  189   190          Venezuela          82
#  190   191              Syria          88
#  191   192  Equatorial Guinea          88
#  192   193       Turkmenistan          88
#  193   194        North Korea          93
#
#       Domain 1: Interactions with Government  \
#  0                                         4
#  1                                         2
#  2                                        16
#  3                                         5
#  4                                        23
#  ..                                      ...
#  189                                      82
#  190                                      91
# ...

# %%
matrix_header =["Rank","Country","Score","Interactions_Government","Deterrence","Transparency","Oversight"]

# %%
#trace_matrix.to_csv('TRACE2022')
import numpy as np

new_df = np.array(trace_matrix[0])

# %%
new_df1 = pd.DataFrame(new_df, columns = matrix_header)

# %%
new_df1
# Out:
#     Rank            Country Score Interactions_Government Deterrence  \
# 0      1             Norway     4                       4          5
# 1      2        New Zealand     8                       2         10
# 2      3             Sweden     9                      16          9
# 3      4        Switzerland    10                       5         14
# 4      5            Denmark    11                      23          1
# ..   ...                ...   ...                     ...        ...
# 189  190          Venezuela    82                      82         84
# 190  191              Syria    88                      91        100
# 191  192  Equatorial Guinea    88                      93         92
# 192  193       Turkmenistan    88                      98         85
# 193  194        North Korea    93                     100         96
#
#     Transparency Oversight
# 0              6         2
# 1             11        13
# 2              1         6
# ...
